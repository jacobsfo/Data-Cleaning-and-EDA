# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/Colab Notebooks/raw_house_data.csv"

# %%
df=pd.read_csv(path)

# %%
df.head()
# Out:
#         MLS  sold_price  zipcode   longitude   latitude  lot_acres     taxes  \
# 0  21530491   5300000.0    85637 -110.378200  31.356362    2154.00   5272.00
# 1  21529082   4200000.0    85646 -111.045371  31.594213    1707.00  10422.36
# 2   3054672   4200000.0    85646 -111.040707  31.594844    1707.00  10482.00
# 3  21919321   4500000.0    85646 -111.035925  31.645878     636.67   8418.58
# 4  21306357   3411450.0    85750 -110.813768  32.285162       3.21  15393.00
#
#    year_built  bedrooms  bathrooms  sqrt_ft  garage  \
# 0        1941        13       10.0  10500.0     0.0
# 1        1997         2        2.0   7300.0     0.0
# 2        1997         2        3.0      NaN     NaN
# 3        1930         7        5.0   9019.0     4.0
# 4        1995         4        6.0   6396.0     3.0
#
#                                     kitchen_features fireplaces  \
# 0            Dishwasher, Freezer, Refrigerator, Oven          6
# ...

# %%
#delete duplicate records

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MLS               5000 non-null   int64
#  1   sold_price        5000 non-null   float64
#  2   zipcode           5000 non-null   int64
#  3   longitude         5000 non-null   float64
#  4   latitude          5000 non-null   float64
#  5   lot_acres         4990 non-null   float64
#  6   taxes             5000 non-null   float64
#  7   year_built        5000 non-null   int64
#  8   bedrooms          5000 non-null   int64
#  9   bathrooms         4994 non-null   float64
#  10  sqrt_ft           4944 non-null   float64
#  11  garage            4993 non-null   float64
#  12  kitchen_features  4967 non-null   object
#  13  fireplaces        5000 non-null   object
#  14  floor_covering    4999 non-null   object
#  15  HOA               4438 non-null   object
# ...

# %%
df.iloc[0:,0]
# Out:
# 0       21530491
# 1       21529082
# 2        3054672
# 3       21919321
# 4       21306357
#           ...
# 4995    21810382
# 4996    21908591
# 4997    21832452
# 4998    21900515
# 4999     4111490
# Name: MLS, Length: 5000, dtype: int64

# %%
df.describe()
# Out:
#                 MLS    sold_price       zipcode    longitude     latitude  \
# count  5.000000e+03  5.000000e+03   5000.000000  5000.000000  5000.000000
# mean   2.127070e+07  7.746262e+05  85723.025600  -110.912107    32.308512
# std    2.398508e+06  3.185556e+05     38.061712     0.120629     0.178028
# min    3.042851e+06  1.690000e+05  85118.000000  -112.520168    31.356362
# 25%    2.140718e+07  5.850000e+05  85718.000000  -110.979260    32.277484
# 50%    2.161469e+07  6.750000e+05  85737.000000  -110.923420    32.318517
# 75%    2.180480e+07  8.350000e+05  85749.000000  -110.859078    32.394334
# max    2.192856e+07  5.300000e+06  86323.000000  -109.454637    34.927884
#
#          lot_acres         taxes  year_built     bedrooms    bathrooms  \
# count  4990.000000  5.000000e+03  5000.00000  5000.000000  4994.000000
# mean      4.661317  9.402828e+03  1992.32800     3.933800     3.829896
# std      51.685230  1.729385e+05    65.48614     1.245362     1.387063
# ...

# %%
plot_df=df.describe()
plt.figure(figsize=(10,6))
sns.barplot(x=plot_df.columns,y=plot_df.loc['mean'],palette='viridis')
plt.title('Mean of each column')
plt.ylabel('Mean value')
plt.show()
# Out:
# /tmp/ipython-input-433263558.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=plot_df.columns,y=plot_df.loc['mean'],palette='viridis')

# %%
plot_df=df.describe()
plt.figure(figsize=(10,6))
sns.barplot(x=plot_df.columns,y=plot_df.loc['std'],palette='viridis')
plt.title('Standard deviation of each column')
plt.ylabel('Standard deviation')
plt.show()
# Out:
# /tmp/ipython-input-3861894182.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=plot_df.columns,y=plot_df.loc['std'],palette='viridis')

# %%
mls=set(df.iloc[0:,0])

# %%
len(mls)
# Out:
# 5000

# %%
len(df.iloc[0:,0])
# Out:
# 5000

# %%
print(df.isnull().sum())
# Out:
# MLS                   0
# sold_price            0
# zipcode               0
# longitude             0
# latitude              0
# lot_acres            10
# taxes                 0
# year_built            0
# bedrooms              0
# bathrooms             6
# sqrt_ft              56
# garage                7
# kitchen_features     33
# fireplaces            0
# floor_covering        1
# HOA                 562
# dtype: int64

# %%
lot_acres_rep=df['lot_acres'].median()

# %%
len(df[df['lot_acres']==0.0])
# Out:
# 35

# %%
df.fillna({"lot_acres": lot_acres_rep}, inplace=True)

# %%
(df[df['lot_acres']==lot_acres_rep])
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 139   21219636   1650000.0    85718 -110.943145  32.350142       0.99
# 364   21900170   1250000.0    85755 -110.966696  32.460850       0.99
# 371   21305294   1200000.0    85718 -110.942288  32.347119       0.99
# 433   21916349   1250000.0    85718 -110.941439  32.343458       0.99
# 436   21418351   1180000.0    85750 -110.859923  32.318022       0.99
# 461   21125519   1090000.0    85718 -110.939505  32.340569       0.99
# 504   21625779   1050000.0    85718 -110.940565  32.343649       0.99
# 698   21604918    950000.0    85718 -110.886010  32.332040       0.99
# 749   21625545    982500.0    85750 -110.864263  32.318603       0.99
# 918   21915587    940000.0    85718 -110.941911  32.341037       0.99
# 967    3058213    695000.0    85645 -111.183593  31.702330       0.99
# 1202  21620598    855000.0    85750 -110.866428  32.329549       0.99
# ...

# %%
len(df[df['lot_acres']==lot_acres_rep])
# Out:
# 38

# %%
print(df.isnull().sum())
# Out:
# MLS                   0
# sold_price            0
# zipcode               0
# longitude             0
# latitude              0
# lot_acres             0
# taxes                 0
# year_built            0
# bedrooms              0
# bathrooms             6
# sqrt_ft              56
# garage                7
# kitchen_features     33
# fireplaces            0
# floor_covering        1
# HOA                 562
# dtype: int64

# %%
sqrt_rep=df['sqrt_ft'].median()

# %%
sqrt_rep
# Out:
# 3512.0

# %%
df.fillna({"sqrt_ft": sqrt_rep}, inplace=True)

# %%
(df[df['sqrt_ft']==sqrt_rep])
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 2      3054672   4200000.0    85646 -111.040707  31.594844    1707.00
# 490    3055989    950000.0    85646 -111.073405  31.619537       4.40
# 967    3058213    695000.0    85645 -111.183593  31.702330       0.99
# 1064   3056708    785045.0    85646 -110.942060  31.552399      73.42
# 1373   3059704    750000.0    85622 -111.001762  31.841975       2.72
# 1659   3055188    700000.0    85646 -111.046366  31.623839       0.99
# 1728   3057818    565000.0    85646 -111.050885  31.627210       0.72
# 1729   3044500    675000.0    85629 -110.961128  31.869810       1.02
# 1730   3053678    700000.0    85645 -111.239637  31.662369     172.76
# 1731   3059581    715000.0    85622 -111.040615  31.804808       4.72
# 1863   3052969    750000.0    85622 -111.002640  31.846861       4.58
# 2025   3044867    660000.0    85614 -110.969465  31.836723       3.60
# ...

# %%
len((df[df['sqrt_ft']==sqrt_rep]))
# Out:
# 58

# %%
print(df.isnull().sum())
# Out:
# MLS                   0
# sold_price            0
# zipcode               0
# longitude             0
# latitude              0
# lot_acres             0
# taxes                 0
# year_built            0
# bedrooms              0
# bathrooms             6
# sqrt_ft               0
# garage                7
# kitchen_features     33
# fireplaces            0
# floor_covering        1
# HOA                 562
# dtype: int64

# %%
len(df[df['taxes']==0.0])
# Out:
# 22

# %%
taxes_rep=df['taxes'].median()

# %%
taxes_rep
# Out:
# 6223.76

# %%
df.iloc[100:,:]
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 100   21522589   2100000.0    85718 -110.885186  32.327907       1.55
# 101   21814436   1450000.0    85624 -110.738083  31.533643     164.30
# 102   21326674   1700000.0    85750 -110.846362  32.329630       1.12
# 103   21601186   1625000.0    85718 -110.935902  32.305132       4.01
# 104   21601560   1500000.0    85718 -110.949807  32.344544       1.36
# ...        ...         ...      ...         ...        ...        ...
# 4995  21810382    495000.0    85641 -110.661829  31.907917       4.98
# 4996  21908591    550000.0    85750 -110.858556  32.316373       1.42
# 4997  21832452    475000.0    85192 -110.755428  32.964708      12.06
# 4998  21900515    550000.0    85745 -111.055528  32.296871       1.01
# 4999   4111490    450000.0    85621 -110.913054  31.385259       4.16
#
#          taxes  year_built  bedrooms  bathrooms  sqrt_ft  garage  \
# ...

# %%
taxes=list(df['taxes'])

# %%
df.iloc[100:,:]
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 100   21522589   2100000.0    85718 -110.885186  32.327907       1.55
# 101   21814436   1450000.0    85624 -110.738083  31.533643     164.30
# 102   21326674   1700000.0    85750 -110.846362  32.329630       1.12
# 103   21601186   1625000.0    85718 -110.935902  32.305132       4.01
# 104   21601560   1500000.0    85718 -110.949807  32.344544       1.36
# ...        ...         ...      ...         ...        ...        ...
# 4995  21810382    495000.0    85641 -110.661829  31.907917       4.98
# 4996  21908591    550000.0    85750 -110.858556  32.316373       1.42
# 4997  21832452    475000.0    85192 -110.755428  32.964708      12.06
# 4998  21900515    550000.0    85745 -111.055528  32.296871       1.01
# 4999   4111490    450000.0    85621 -110.913054  31.385259       4.16
#
#          taxes  year_built  bedrooms  bathrooms  sqrt_ft  garage  \
# ...

# %%
taxes= [taxes_rep if x == 0.0 else x for x in taxes]

# %%
taxes
# Out:
# [5272.0,
#  10422.36,
#  10482.0,
#  8418.58,
#  15393.0,
#  27802.84,
#  19038.42,
#  21646.0,
#  25094.39,
#  18936.11,
#  7330.36,
#  24353.0,
#  11723.0,
#  5198.58,
#  29669.0,
#  18044.0,
#  24040.26,
#  19565.2,
#  17567.18,
#  22320.0,
#  8753.35,
#  11322.0,
#  22655.99,
#  16354.0,
#  13519.82,
#  22070.48,
#  30072.26,
#  31275.0,
#  21795.32,
#  2441.6,
#  5931.0,
#  5785.0,
#  16714.0,
#  26856.69,
#  20960.92,
#  1220.32,
#  16276.0,
#  20084.0,
#  3902.0,
#  3902.44,
#  1286.59,
#  16052.89,
#  26642.7,
#  20530.88,
#  6656.2,
#  26641.26,
#  1896.71,
#  7292.0,
#  22677.81,
#  4509.9,
#  20206.0,
#  14631.69,
#  21063.0,
#  19060.81,
#  32442.22,
#  24316.0,
#  15250.76,
#  10956.02,
#  1340.87,
#  17077.5,
#  3292.0,
#  7069.16,
#  8411.94,
#  14425.8,
#  14748.57,
#  14202.0,
#  27781.84,
#  23156.58,
#  10780.0,
#  21910.0,
#  4127.07,
#  10191.82,
#  12074.17,
#  3767.38,
#  23880.63,
#  12529.0,
#  8602.57,
#  21083.04,
#  25315.81,
#  11690.67,
#  16702.0,
# ...

# %%
df['taxes']=taxes

# %%
(df[df['taxes']==taxes_rep])
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 101   21814436   1450000.0    85624 -110.738083  31.533643     164.30
# 196   21624122   1547664.0    85719 -110.934183  32.244512       0.20
# 377   21706833   1408464.0    85719 -110.938327  32.242829       0.24
# 723   21624132   1048842.0    85719 -110.938291  32.242845       0.23
# 725   21730800   1069000.0    85719 -110.939051  32.243662       0.20
# 775   21730798   1007583.0    85719 -110.938306  32.243724       0.21
# 800   21730799    972877.0    85719 -110.939406  32.243494       0.21
# 909   21730830    985368.0    85719 -110.939446  32.243699       0.21
# 930   21730801    950795.0    85719 -110.938701  32.243375       0.20
# 1066  21730831    900000.0    85719 -110.939027  32.243327       0.20
# 1427  21522262    809310.0    85755 -110.976076  32.459110       0.96
# 1518  21811216    809400.0    85737 -110.961063  32.409852       0.46
# ...

# %%
len(df[df['taxes']==taxes_rep])
# Out:
# 22

# %%
df.iloc[100:,:]
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 100   21522589   2100000.0    85718 -110.885186  32.327907       1.55
# 101   21814436   1450000.0    85624 -110.738083  31.533643     164.30
# 102   21326674   1700000.0    85750 -110.846362  32.329630       1.12
# 103   21601186   1625000.0    85718 -110.935902  32.305132       4.01
# 104   21601560   1500000.0    85718 -110.949807  32.344544       1.36
# ...        ...         ...      ...         ...        ...        ...
# 4995  21810382    495000.0    85641 -110.661829  31.907917       4.98
# 4996  21908591    550000.0    85750 -110.858556  32.316373       1.42
# 4997  21832452    475000.0    85192 -110.755428  32.964708      12.06
# 4998  21900515    550000.0    85745 -111.055528  32.296871       1.01
# 4999   4111490    450000.0    85621 -110.913054  31.385259       4.16
#
#          taxes  year_built  bedrooms  bathrooms  sqrt_ft  garage  \
# ...

# %%
print(df.isnull().sum())
# Out:
# MLS                   0
# sold_price            0
# zipcode               0
# longitude             0
# latitude              0
# lot_acres             0
# taxes                 0
# year_built            0
# bedrooms              0
# bathrooms             6
# sqrt_ft               0
# garage                7
# kitchen_features     33
# fireplaces            0
# floor_covering        1
# HOA                 562
# dtype: int64

# %%
len(df[df['HOA']==56.0])
# Out:
# 0

# %%
df['HOA']=df['HOA'].str.replace(',','')

# %%
df.iloc[425:,:]
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 425   21123767   1000000.0    85742 -111.027855  32.356862       1.30
# 426   21809350   1250000.0    85750 -110.842620  32.294969       1.13
# 427   21308169   1225000.0    85750 -110.855813  32.326515       1.45
# 428   21703603   1125478.0    85755 -110.973498  32.460529       1.71
# 429   21807764   1150000.0    85743 -111.104033  32.308202       3.54
# ...        ...         ...      ...         ...        ...        ...
# 4995  21810382    495000.0    85641 -110.661829  31.907917       4.98
# 4996  21908591    550000.0    85750 -110.858556  32.316373       1.42
# 4997  21832452    475000.0    85192 -110.755428  32.964708      12.06
# 4998  21900515    550000.0    85745 -111.055528  32.296871       1.01
# 4999   4111490    450000.0    85621 -110.913054  31.385259       4.16
#
#          taxes  year_built  bedrooms  bathrooms  sqrt_ft  garage  \
# ...

# %%
df['HOA']=df['HOA'].str.replace(' ','')

# %%
df['HOA']=df['HOA'].astype(float)

# %%
df['HOA'].dtype
# Out:
# dtype('float64')

# %%
hoa_rep=df['HOA'].median()

# %%
hoa_rep
# Out:
# 56.0

# %%
df.fillna({'HOA': hoa_rep}, inplace=True)

# %%
df[df['HOA']==hoa_rep]
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 2      3054672   4200000.0    85646 -111.040707  31.594844    1707.00
# 3     21919321   4500000.0    85646 -111.035925  31.645878     636.67
# 10    21900396   2776518.0    85640 -111.045441  31.562121     147.18
# 39     4113243   2200000.0    85640 -111.044630  31.562185     147.18
# 49    21818418   1800000.0    86024 -111.228462  34.596971      59.30
# ...        ...         ...      ...         ...        ...        ...
# 4990  21906583    526710.0    85748 -110.728390  32.221871       9.18
# 4995  21810382    495000.0    85641 -110.661829  31.907917       4.98
# 4997  21832452    475000.0    85192 -110.755428  32.964708      12.06
# 4998  21900515    550000.0    85745 -111.055528  32.296871       1.01
# 4999   4111490    450000.0    85621 -110.913054  31.385259       4.16
#
#          taxes  year_built  bedrooms  bathrooms  sqrt_ft  garage  \
# ...

# %%
len((df[df['HOA']==hoa_rep]))
# Out:
# 576

# %%
print(df.isnull().sum())
# Out:
# MLS                  0
# sold_price           0
# zipcode              0
# longitude            0
# latitude             0
# lot_acres            0
# taxes                0
# year_built           0
# bedrooms             0
# bathrooms            6
# sqrt_ft              0
# garage               7
# kitchen_features    33
# fireplaces           0
# floor_covering       1
# HOA                  0
# dtype: int64

# %%
df.fillna({'garage': df['garage'].median()}, inplace=True)

# %%
print(df.isnull().sum())
# Out:
# MLS                  0
# sold_price           0
# zipcode              0
# longitude            0
# latitude             0
# lot_acres            0
# taxes                0
# year_built           0
# bedrooms             0
# bathrooms            6
# sqrt_ft              0
# garage               0
# kitchen_features    33
# fireplaces           0
# floor_covering       1
# HOA                  0
# dtype: int64

# %%
garage=[math.ceil(x) for x in list(df['garage'])]

# %%
df.iloc[325:,:]
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 325   21229423   1374000.0    85750 -110.825236  32.283340       0.86
# 326   21225844   1235000.0    85658 -111.059255  32.473121       2.20
# 327   21612303   1335000.0    85715 -110.852876  32.256085       1.13
# 328   21400071   1345000.0    85718 -110.943732  32.337931       0.91
# 329   21700619   1330000.0    85718 -110.911566  32.336725       0.87
# ...        ...         ...      ...         ...        ...        ...
# 4995  21810382    495000.0    85641 -110.661829  31.907917       4.98
# 4996  21908591    550000.0    85750 -110.858556  32.316373       1.42
# 4997  21832452    475000.0    85192 -110.755428  32.964708      12.06
# 4998  21900515    550000.0    85745 -111.055528  32.296871       1.01
# 4999   4111490    450000.0    85621 -110.913054  31.385259       4.16
#
#          taxes  year_built  bedrooms  bathrooms  sqrt_ft  garage  \
# ...

# %%
df['garage']=garage

# %%
df.iloc[325:,:]
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 325   21229423   1374000.0    85750 -110.825236  32.283340       0.86
# 326   21225844   1235000.0    85658 -111.059255  32.473121       2.20
# 327   21612303   1335000.0    85715 -110.852876  32.256085       1.13
# 328   21400071   1345000.0    85718 -110.943732  32.337931       0.91
# 329   21700619   1330000.0    85718 -110.911566  32.336725       0.87
# ...        ...         ...      ...         ...        ...        ...
# 4995  21810382    495000.0    85641 -110.661829  31.907917       4.98
# 4996  21908591    550000.0    85750 -110.858556  32.316373       1.42
# 4997  21832452    475000.0    85192 -110.755428  32.964708      12.06
# 4998  21900515    550000.0    85745 -111.055528  32.296871       1.01
# 4999   4111490    450000.0    85621 -110.913054  31.385259       4.16
#
#          taxes  year_built  bedrooms  bathrooms  sqrt_ft  garage  \
# ...

# %%
print(df.isnull().sum())
# Out:
# MLS                  0
# sold_price           0
# zipcode              0
# longitude            0
# latitude             0
# lot_acres            0
# taxes                0
# year_built           0
# bedrooms             0
# bathrooms            6
# sqrt_ft              0
# garage               0
# kitchen_features    33
# fireplaces           0
# floor_covering       1
# HOA                  0
# dtype: int64

# %%
df.fillna({'bathrooms': df['bathrooms'].median()}, inplace=True)

# %%
print(df.isnull().sum())
# Out:
# MLS                  0
# sold_price           0
# zipcode              0
# longitude            0
# latitude             0
# lot_acres            0
# taxes                0
# year_built           0
# bedrooms             0
# bathrooms            0
# sqrt_ft              0
# garage               0
# kitchen_features    33
# fireplaces           0
# floor_covering       1
# HOA                  0
# dtype: int64

# %%
years_rep=df['year_built'].median()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MLS               5000 non-null   int64
#  1   sold_price        5000 non-null   float64
#  2   zipcode           5000 non-null   int64
#  3   longitude         5000 non-null   float64
#  4   latitude          5000 non-null   float64
#  5   lot_acres         5000 non-null   float64
#  6   taxes             5000 non-null   float64
#  7   year_built        5000 non-null   int64
#  8   bedrooms          5000 non-null   int64
#  9   bathrooms         5000 non-null   float64
#  10  sqrt_ft           5000 non-null   float64
#  11  garage            5000 non-null   int64
#  12  kitchen_features  4967 non-null   object
#  13  fireplaces        5000 non-null   object
#  14  floor_covering    4999 non-null   object
#  15  HOA               5000 non-null   float64
# ...

# %%
years= [years_rep if x == 0 else x for x in list(df['year_built'])]

# %%
len(df[df['year_built']==years_rep])
# Out:
# 169

# %%
df['year_built']=years

# %%
df['year_built']!=0
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 4995    True
# 4996    True
# 4997    True
# 4998    True
# 4999    True
# Name: year_built, Length: 5000, dtype: bool

# %%
df.fillna({'kitchen_features': 'Dishwasher, Garbage Disposal, Refrigerator, Microwave, Oven'}, inplace=True)

# %%
print(df.isnull().sum())
# Out:
# MLS                 0
# sold_price          0
# zipcode             0
# longitude           0
# latitude            0
# lot_acres           0
# taxes               0
# year_built          0
# bedrooms            0
# bathrooms           0
# sqrt_ft             0
# garage              0
# kitchen_features    0
# fireplaces          0
# floor_covering      1
# HOA                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MLS               5000 non-null   int64
#  1   sold_price        5000 non-null   float64
#  2   zipcode           5000 non-null   int64
#  3   longitude         5000 non-null   float64
#  4   latitude          5000 non-null   float64
#  5   lot_acres         5000 non-null   float64
#  6   taxes             5000 non-null   float64
#  7   year_built        5000 non-null   float64
#  8   bedrooms          5000 non-null   int64
#  9   bathrooms         5000 non-null   float64
#  10  sqrt_ft           5000 non-null   float64
#  11  garage            5000 non-null   int64
#  12  kitchen_features  4967 non-null   object
#  13  fireplaces        5000 non-null   object
#  14  floor_covering    4999 non-null   object
#  15  HOA               5000 non-null   float64
# ...

# %%
cols=['sold_price','zipcode','longitude','latitude','lot_acres','taxes','year_built','bedrooms','bathrooms','sqrt_ft','garage','kitchen_features','fireplaces','floor_covering','HOA']

# %%
for col in cols:
  print(df[col]==' ')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: sold_price, Length: 5000, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: zipcode, Length: 5000, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: longitude, Length: 5000, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: latitude, Length: 5000, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# ...

# %%
df.describe()
# Out:
#                 MLS    sold_price       zipcode    longitude     latitude  \
# count  5.000000e+03  5.000000e+03   5000.000000  5000.000000  5000.000000
# mean   2.127070e+07  7.746262e+05  85723.025600  -110.912107    32.308512
# std    2.398508e+06  3.185556e+05     38.061712     0.120629     0.178028
# min    3.042851e+06  1.690000e+05  85118.000000  -112.520168    31.356362
# 25%    2.140718e+07  5.850000e+05  85718.000000  -110.979260    32.277484
# 50%    2.161469e+07  6.750000e+05  85737.000000  -110.923420    32.318517
# 75%    2.180480e+07  8.350000e+05  85749.000000  -110.859078    32.394334
# max    2.192856e+07  5.300000e+06  86323.000000  -109.454637    34.927884
#
#          lot_acres         taxes   year_built     bedrooms    bathrooms  \
# count  5000.000000  5.000000e+03  5000.000000  5000.000000  5000.000000
# mean      4.653974  9.430213e+03  1994.327000     3.933800     3.830100
# std      51.633769  1.729375e+05    17.728997     1.245362     1.386243
# ...

# %%
df
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 0     21530491   5300000.0    85637 -110.378200  31.356362    2154.00
# 1     21529082   4200000.0    85646 -111.045371  31.594213    1707.00
# 2      3054672   4200000.0    85646 -111.040707  31.594844    1707.00
# 3     21919321   4500000.0    85646 -111.035925  31.645878     636.67
# 4     21306357   3411450.0    85750 -110.813768  32.285162       3.21
# ...        ...         ...      ...         ...        ...        ...
# 4995  21810382    495000.0    85641 -110.661829  31.907917       4.98
# 4996  21908591    550000.0    85750 -110.858556  32.316373       1.42
# 4997  21832452    475000.0    85192 -110.755428  32.964708      12.06
# 4998  21900515    550000.0    85745 -111.055528  32.296871       1.01
# 4999   4111490    450000.0    85621 -110.913054  31.385259       4.16
#
#          taxes  year_built  bedrooms  bathrooms  sqrt_ft  garage  \
# ...

# %%
plot_df=df.describe()
plt.figure(figsize=(10,6))
sns.barplot(x=plot_df.columns,y=plot_df.loc['mean'],palette='viridis')
plt.title('Mean of each column')
plt.ylabel('Mean value')
plt.show()
# Out:
# /tmp/ipython-input-433263558.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=plot_df.columns,y=plot_df.loc['mean'],palette='viridis')

# %%
plot_df=df.describe()
plt.figure(figsize=(10,6))
sns.barplot(x=plot_df.columns,y=plot_df.loc['std'],palette='viridis')
plt.title('Standard deviation of each column')
plt.ylabel('Standard deviation')
plt.show()
# Out:
# /tmp/ipython-input-3861894182.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=plot_df.columns,y=plot_df.loc['std'],palette='viridis')

# %%
plot_df
# Out:
#                 MLS    sold_price       zipcode    longitude     latitude  \
# count  5.000000e+03  5.000000e+03   5000.000000  5000.000000  5000.000000
# mean   2.127070e+07  7.746262e+05  85723.025600  -110.912107    32.308512
# std    2.398508e+06  3.185556e+05     38.061712     0.120629     0.178028
# min    3.042851e+06  1.690000e+05  85118.000000  -112.520168    31.356362
# 25%    2.140718e+07  5.850000e+05  85718.000000  -110.979260    32.277484
# 50%    2.161469e+07  6.750000e+05  85737.000000  -110.923420    32.318517
# 75%    2.180480e+07  8.350000e+05  85749.000000  -110.859078    32.394334
# max    2.192856e+07  5.300000e+06  86323.000000  -109.454637    34.927884
#
#          lot_acres         taxes   year_built     bedrooms    bathrooms  \
# count  5000.000000  5.000000e+03  5000.000000  5000.000000  5000.000000
# mean      4.653974  9.430213e+03  1994.327000     3.933800     3.830100
# std      51.633769  1.729375e+05    17.728997     1.245362     1.386243
# ...

# %%
df
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 0     21530491   5300000.0    85637 -110.378200  31.356362    2154.00
# 1     21529082   4200000.0    85646 -111.045371  31.594213    1707.00
# 2      3054672   4200000.0    85646 -111.040707  31.594844    1707.00
# 3     21919321   4500000.0    85646 -111.035925  31.645878     636.67
# 4     21306357   3411450.0    85750 -110.813768  32.285162       3.21
# ...        ...         ...      ...         ...        ...        ...
# 4995  21810382    495000.0    85641 -110.661829  31.907917       4.98
# 4996  21908591    550000.0    85750 -110.858556  32.316373       1.42
# 4997  21832452    475000.0    85192 -110.755428  32.964708      12.06
# 4998  21900515    550000.0    85745 -111.055528  32.296871       1.01
# 4999   4111490    450000.0    85621 -110.913054  31.385259       4.16
#
#          taxes  year_built  bedrooms  bathrooms  sqrt_ft  garage  \
# ...

# %%
sns.boxplot(x=df['lot_acres'])
# Out:
# <Axes: xlabel='lot_acres'>

# %%
sns.boxplot(x=df['sqrt_ft'])
# Out:
# <Axes: xlabel='sqrt_ft'>

# %%
df.to_csv(path)

# %%
df
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 0     21530491   5300000.0    85637 -110.378200  31.356362    2154.00
# 1     21529082   4200000.0    85646 -111.045371  31.594213    1707.00
# 2      3054672   4200000.0    85646 -111.040707  31.594844    1707.00
# 3     21919321   4500000.0    85646 -111.035925  31.645878     636.67
# 4     21306357   3411450.0    85750 -110.813768  32.285162       3.21
# ...        ...         ...      ...         ...        ...        ...
# 4995  21810382    495000.0    85641 -110.661829  31.907917       4.98
# 4996  21908591    550000.0    85750 -110.858556  32.316373       1.42
# 4997  21832452    475000.0    85192 -110.755428  32.964708      12.06
# 4998  21900515    550000.0    85745 -111.055528  32.296871       1.01
# 4999   4111490    450000.0    85621 -110.913054  31.385259       4.16
#
#          taxes  year_built  bedrooms  bathrooms  sqrt_ft  garage  \
# ...
